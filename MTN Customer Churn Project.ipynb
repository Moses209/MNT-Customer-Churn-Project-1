# %%
#MTN Nigeria Custormer Churn
http://localhost:8888/edit/Documents/mtn_customer_churn.csv
#import kagglehub

# Download latest version
path = kagglehub.dataset_download("oluwademiladeadeniyi/mtn-nigeria-customer-churn")

print("Path to dataset files:", path)

# %%
#Hypothesis:
#Customers with lower satisfaction rates more likely to churn
#shorter tenures more likely to churn
#lower data usage likely to churn from MTN Nigeria.

# %%
import pandas as pd
df = pd.read_csv("mtn_customer_churn.csv")
df
# Out:
#     Customer ID        Full Name Date of Purchase  Age        State  \
# 0      CUST0001      Ngozi Berry           Jan-25   27        Kwara
# 1      CUST0002     Zainab Baker           Mar-25   16  Abuja (FCT)
# 2      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 3      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 4      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# ..          ...              ...              ...  ...          ...
# 969    CUST0498     Shehu Harris           Jan-25   72         Osun
# 970    CUST0499        Tega Hood           Mar-25   41      Bayelsa
# 971    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 972    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 973    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
#
#               MTN Device  Gender  Satisfaction Rate Customer Review  \
# 0              4G Router    Male                  2            Fair
# ...

# %%
df.columns
df
# Out:
#     Customer ID        Full Name Date of Purchase  Age        State  \
# 0      CUST0001      Ngozi Berry           Jan-25   27        Kwara
# 1      CUST0002     Zainab Baker           Mar-25   16  Abuja (FCT)
# 2      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 3      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 4      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# ..          ...              ...              ...  ...          ...
# 969    CUST0498     Shehu Harris           Jan-25   72         Osun
# 970    CUST0499        Tega Hood           Mar-25   41      Bayelsa
# 971    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 972    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 973    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
#
#               MTN Device  Gender  Satisfaction Rate Customer Review  \
# 0              4G Router    Male                  2            Fair
# ...

# %%
# Null values
df.isnull().any()
df
# Out:
#     Customer ID        Full Name Date of Purchase  Age        State  \
# 0      CUST0001      Ngozi Berry           Jan-25   27        Kwara
# 1      CUST0002     Zainab Baker           Mar-25   16  Abuja (FCT)
# 2      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 3      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# 4      CUST0003      Saidu Evans           Mar-25   21       Sokoto
# ..          ...              ...              ...  ...          ...
# 969    CUST0498     Shehu Harris           Jan-25   72         Osun
# 970    CUST0499        Tega Hood           Mar-25   41      Bayelsa
# 971    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 972    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
# 973    CUST0500  Oghene Hamilton           Feb-25   67        Kebbi
#
#               MTN Device  Gender  Satisfaction Rate Customer Review  \
# 0              4G Router    Male                  2            Fair
# ...

# %%
# To drop the columns that are not necessary for our findings.
df_columns = df.drop(['Full Name', 'MTN Device','Subscription Plan', 'Date of Purchase','Age','Gender',
                      'Customer Review','Unit Price','Number of Times Purchased','Reasons for Churn',
                      'Total Revenue',], axis=1, inplace=True)
df
# Out:
#     Customer ID        State  Satisfaction Rate  Customer Tenure in months  \
# 0      CUST0001        Kwara                  2                          2
# 1      CUST0002  Abuja (FCT)                  2                         22
# 2      CUST0003       Sokoto                  1                         60
# 3      CUST0003       Sokoto                  1                         60
# 4      CUST0003       Sokoto                  1                         60
# ..          ...          ...                ...                        ...
# 969    CUST0498         Osun                  3                         42
# 970    CUST0499      Bayelsa                  2                         20
# 971    CUST0500        Kebbi                  4                         31
# 972    CUST0500        Kebbi                  4                         31
# 973    CUST0500        Kebbi                  4                         31
#
#      Data Usage Customer Churn Status
# ...

# %%
#To check and drop all the duplication value
df.drop_duplicates()
df
# Out:
#     Customer ID        State  Satisfaction Rate  Customer Tenure in months  \
# 0      CUST0001        Kwara                  2                          2
# 1      CUST0002  Abuja (FCT)                  2                         22
# 2      CUST0003       Sokoto                  1                         60
# 3      CUST0003       Sokoto                  1                         60
# 4      CUST0003       Sokoto                  1                         60
# ..          ...          ...                ...                        ...
# 969    CUST0498         Osun                  3                         42
# 970    CUST0499      Bayelsa                  2                         20
# 971    CUST0500        Kebbi                  4                         31
# 972    CUST0500        Kebbi                  4                         31
# 973    CUST0500        Kebbi                  4                         31
#
#      Data Usage Customer Churn Status
# ...

# %%
import pandas as pd
df2 = pd.read_excel(r"C:\Data Analyist\Data Analysis week 3\List_of_Nigerian_states_by_population (2).xlsx")
df2
# Out:
#            List of Nigerian states by population  Unnamed: 1  Unnamed: 2  \
# 0   Map of Nigerian states by population density         NaN         NaN
# 1                                            NaN         NaN         NaN
# 2                                            NaN         NaN         NaN
# 3                                            NaN         NaN         NaN
# 4                                          State  Population         NaN
# 5                                            NaN        2006      2020.0
# 6                                     Kano State     9401288  16253549.0
# 7                                    Lagos State     9113605  15772884.0
# 8                                  Katsina State     5801584   9300382.0
# 9                                   Kaduna State     6113503   8324285.0
# 10                                  Bauchi State     4653066   7540663.0
# 11                                     Oyo State     5580894   7512855.0
# ...

# %%
#To check for the headers column
df2.columns
# Out:
# Index(['List of Nigerian states by population', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
# Remove first 6 rows (index 0-5)
df2 = df2.iloc[6:]
df2
# Out:
#    List of Nigerian states by population Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 6                             Kano State    9401288  16253549.0      20131
# 7                            Lagos State    9113605  15772884.0       3345
# 8                          Katsina State    5801584   9300382.0      24192
# 9                           Kaduna State    6113503   8324285.0      46053
# 10                          Bauchi State    4653066   7540663.0      45893
# 11                             Oyo State    5580894   7512855.0      28454
# 12                         Anambra State    5177828   7299910.0       4844
# 13                          Rivers State    5198716   7234973.0      11077
# 14                          Jigawa State    4361002   6979080.0      23154
# 15                           Niger State    3954772   6720617.0      76363
# 16                           Benue State    4253641   6687706.0      34059
# ...

# %%
#To rename the column heading
df2 = df2.rename(columns={'List of Nigerian states by population': 'State', 'Unnamed: 1': 'Population(2006)',
                        'Unnamed: 2': 'Population(2020)','Unnamed: 3':'Area (km2)', 'Unnamed: 4': 'Density (2006) (per km2)',
                        'Unnamed: 5':'Density (2020) (per km2)'})
df2
# Out:
#                         State Population(2006)  Population(2020) Area (km2)  \
# 6                  Kano State          9401288        16253549.0      20131
# 7                 Lagos State          9113605        15772884.0       3345
# 8               Katsina State          5801584         9300382.0      24192
# 9                Kaduna State          6113503         8324285.0      46053
# 10               Bauchi State          4653066         7540663.0      45893
# 11                  Oyo State          5580894         7512855.0      28454
# 12              Anambra State          5177828         7299910.0       4844
# 13               Rivers State          5198716         7234973.0      11077
# 14               Jigawa State          4361002         6979080.0      23154
# 15                Niger State          3954772         6720617.0      76363
# 16                Benue State          4253641         6687706.0      34059
# ...

# %%
#To drop the column that were not necessary for this analysis
df2 = df2.drop(['Population(2006)', 'Area (km2)', 'Density (2006) (per km2)', 'Density (2020) (per km2)'], axis=1)
df2
# Out:
#                         State  Population(2020)
# 6                  Kano State        16253549.0
# 7                 Lagos State        15772884.0
# 8               Katsina State         9300382.0
# 9                Kaduna State         8324285.0
# 10               Bauchi State         7540663.0
# 11                  Oyo State         7512855.0
# 12              Anambra State         7299910.0
# 13               Rivers State         7234973.0
# 14               Jigawa State         6979080.0
# 15                Niger State         6720617.0
# 16                Benue State         6687706.0
# 17                Borno State         6651590.0
# 18                 Ogun State         6445275.0
# 19               Sokoto State         6163187.0
# 20                Delta State         7107543.0
# 21                  Imo State         6067722.0
# 22                Kebbi State         6001610.0
# 23                 Ondo State         5469707.0
# 24            Akwa Ibom State         5780581.0
# ...

# %%
# Remove " State" from the end
df2['State'] = df2['State'].str.replace(r'\s+[Ss]tate\b', '', regex=True)
df2
# Out:
#                         State  Population(2020)
# 6                        Kano        16253549.0
# 7                       Lagos        15772884.0
# 8                     Katsina         9300382.0
# 9                      Kaduna         8324285.0
# 10                     Bauchi         7540663.0
# 11                        Oyo         7512855.0
# 12                    Anambra         7299910.0
# 13                     Rivers         7234973.0
# 14                     Jigawa         6979080.0
# 15                      Niger         6720617.0
# 16                      Benue         6687706.0
# 17                      Borno         6651590.0
# 18                       Ogun         6445275.0
# 19                     Sokoto         6163187.0
# 20                      Delta         7107543.0
# 21                        Imo         6067722.0
# 22                      Kebbi         6001610.0
# 23                       Ondo         5469707.0
# 24                  Akwa Ibom         5780581.0
# ...

# %%
# Display the updated State column in oder to check for unique character
print(df2['State'].unique())  # Verify changes
# Out:
# ['Kano' 'Lagos' 'Katsina' 'Kaduna' 'Bauchi' 'Oyo' 'Anambra' 'Rivers'
#  'Jigawa' 'Niger' 'Benue' 'Borno' 'Ogun' 'Sokoto' 'Delta' 'Imo' 'Kebbi'
#  'Ondo' 'Akwa\xa0Ibom' 'Edo' 'Zamfara' 'Plateau' 'Enugu' 'Adamawa' 'Kogi'
#  'Abia' 'Federal\xa0Capital\xa0Territory' 'Gombe' 'Yobe' 'Taraba' 'Kwara'
#  'Osun' 'Cross\xa0River' 'Ebonyi' 'Nasarawa' 'Ekiti' 'Bayelsa']

# %%
# Replace "Federal Capital Territory" with "Abuja (FCT)"
df2['State'] = df2['State'].str.replace('Federal\xa0Capital\xa0Territory', 'Abuja (FCT)', regex=False)
df2
# Out:
#           State  Population(2020)
# 6          Kano        16253549.0
# 7         Lagos        15772884.0
# 8       Katsina         9300382.0
# 9        Kaduna         8324285.0
# 10       Bauchi         7540663.0
# 11          Oyo         7512855.0
# 12      Anambra         7299910.0
# 13       Rivers         7234973.0
# 14       Jigawa         6979080.0
# 15        Niger         6720617.0
# 16        Benue         6687706.0
# 17        Borno         6651590.0
# 18         Ogun         6445275.0
# 19       Sokoto         6163187.0
# 20        Delta         7107543.0
# 21          Imo         6067722.0
# 22        Kebbi         6001610.0
# 23         Ondo         5469707.0
# 24    Akwa Ibom         5780581.0
# 25          Edo         5527810.0
# 26      Zamfara         5517793.0
# 27      Plateau         5400974.0
# 28        Enugu         5396098.0
# 29      Adamawa         5236948.0
# 30         Kogi         5053734.0
# 31         Abia         4841943.0
# ...

# %%
# Remove trailing zeros after the decimal
df2['Population(2020)'] = pd.to_numeric(df2['Population(2020)'],
                    errors='coerce').astype(float).astype(str).str.replace(r'\.0+$', '', regex=True).str.replace(r'(\..+?)0+$', r'\1', regex=True)
df2
# Out:
#           State Population(2020)
# 6          Kano         16253549
# 7         Lagos         15772884
# 8       Katsina          9300382
# 9        Kaduna          8324285
# 10       Bauchi          7540663
# 11          Oyo          7512855
# 12      Anambra          7299910
# 13       Rivers          7234973
# 14       Jigawa          6979080
# 15        Niger          6720617
# 16        Benue          6687706
# 17        Borno          6651590
# 18         Ogun          6445275
# 19       Sokoto          6163187
# 20        Delta          7107543
# 21          Imo          6067722
# 22        Kebbi          6001610
# 23         Ondo          5469707
# 24    Akwa Ibom          5780581
# 25          Edo          5527810
# 26      Zamfara          5517793
# 27      Plateau          5400974
# 28        Enugu          5396098
# 29      Adamawa          5236948
# 30         Kogi          5053734
# 31         Abia          4841943
# 32  Abuja (FCT)          4802443
# ...

# %%
# Merge Population (2020) from df2 into df based on State
merged_df = pd.merge(
    df,
    df2[['State', 'Population(2020)']],  # Select only State and Population columns from df2
    on='State',
    how='left'  # Keeps all rows from df (use 'inner' to keep only matching states)
)
df
# Out:
#     Customer ID        State  Satisfaction Rate  Customer Tenure in months  \
# 0      CUST0001        Kwara                  2                          2
# 1      CUST0002  Abuja (FCT)                  2                         22
# 2      CUST0003       Sokoto                  1                         60
# 3      CUST0003       Sokoto                  1                         60
# 4      CUST0003       Sokoto                  1                         60
# ..          ...          ...                ...                        ...
# 969    CUST0498         Osun                  3                         42
# 970    CUST0499      Bayelsa                  2                         20
# 971    CUST0500        Kebbi                  4                         31
# 972    CUST0500        Kebbi                  4                         31
# 973    CUST0500        Kebbi                  4                         31
#
#      Data Usage Customer Churn Status
# ...

# %%
# Display the merged DataFrame in oder to re-check if everything is in order
print(merged_df.head())
# Out:
#   Customer ID        State  Satisfaction Rate  Customer Tenure in months  \
# 0    CUST0001        Kwara                  2                          2
# 1    CUST0002  Abuja (FCT)                  2                         22
# 2    CUST0003       Sokoto                  1                         60
# 3    CUST0003       Sokoto                  1                         60
# 4    CUST0003       Sokoto                  1                         60
#
#    Data Usage Customer Churn Status Population(2020)
# 0       44.48                   Yes          4259613
# 1       19.79                   Yes          4802443
# 2        9.64                    No          6163187
# 3      197.05                    No          6163187
# 4       76.34                    No          6163187

# %%
#To call the merge data out
merged_df
# Out:
#     Customer ID        State  Satisfaction Rate  Customer Tenure in months  \
# 0      CUST0001        Kwara                  2                          2
# 1      CUST0002  Abuja (FCT)                  2                         22
# 2      CUST0003       Sokoto                  1                         60
# 3      CUST0003       Sokoto                  1                         60
# 4      CUST0003       Sokoto                  1                         60
# ..          ...          ...                ...                        ...
# 969    CUST0498         Osun                  3                         42
# 970    CUST0499      Bayelsa                  2                         20
# 971    CUST0500        Kebbi                  4                         31
# 972    CUST0500        Kebbi                  4                         31
# 973    CUST0500        Kebbi                  4                         31
#
#      Data Usage Customer Churn Status Population(2020)
# ...

# %%
# Remove 'Population (2020)' from its current position and insert it after 'State'
cols.insert(cols.index('State') + 1, cols.pop(cols.index('Population(2020)')))

# %%
# Reorder the DataFrame
merged_df = merged_df[cols]
merged_df
# Out:
#     Customer ID        State Population(2020)  Satisfaction Rate  \
# 0      CUST0001        Kwara          4259613                  2
# 1      CUST0002  Abuja (FCT)          4802443                  2
# 2      CUST0003       Sokoto          6163187                  1
# 3      CUST0003       Sokoto          6163187                  1
# 4      CUST0003       Sokoto          6163187                  1
# ..          ...          ...              ...                ...
# 969    CUST0498         Osun          4237396                  3
# 970    CUST0499      Bayelsa          2394725                  2
# 971    CUST0500        Kebbi          6001610                  4
# 972    CUST0500        Kebbi          6001610                  4
# 973    CUST0500        Kebbi          6001610                  4
#
#      Customer Tenure in months  Data Usage Customer Churn Status
# 0                            2       44.48                   Yes
# ...

# %%
#We have to import these software: matplotlib is for scientific research analysis and seaborn is for graphical illustration
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Compare average satisfaction rate for churned vs non-churned
avg_satisfaction = merged_df.groupby('Customer Churn Status')['Satisfaction Rate'].mean()
print("Average Satisfaction Rate:\n", avg_satisfaction)
# Out:
# Average Satisfaction Rate:
#  Customer Churn Status
# No     2.905797
# Yes    3.049296
# Name: Satisfaction Rate, dtype: float64

# %%
# Create a DataFrame with the provided averages
avg_satisfaction = pd.DataFrame({
    "Customer Churn Status": ["No", "Yes"],
    "Average Satisfaction Rate": [2.905797, 3.049296]})

# %%
# Plotting
plt.figure(figsize=(6, 4))
sns.barplot(data=avg_satisfaction, x="Customer Churn Status", y="Average Satisfaction Rate", palette="pastel")
plt.title("Average Satisfaction Rate by Churn Status")
plt.xlabel("Churn Status")
plt.ylabel("Average Satisfaction Rate")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Expertlead Admin\AppData\Local\Temp\ipykernel_5080\1545804867.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_satisfaction, x="Customer Churn Status", y="Average Satisfaction Rate", palette="pastel")

# %%
# 2. Compare average tenure
avg_tenure = merged_df.groupby('Customer Churn Status')['Customer Tenure in months'].mean()
print("\nAverag Customer Tenure in months:\n", avg_tenure)
# Out:
# Averag Customer Tenure in months:
#  Customer Churn Status
# No     30.724638
# Yes    33.119718
# Name: Customer Tenure in months, dtype: float64

# %%
# Create a DataFrame with the provided averages
avg_tenure = pd.DataFrame({
    "Customer Churn Status": ["No", "Yes"],
    "Average Customer Tenure in months": [30.724638, 33.119718]})

# %%
# Plotting
plt.figure(figsize=(6, 4))
sns.barplot(data=avg_tenure, x="Customer Churn Status", y="Average Customer Tenure in months", palette="pastel")
plt.title("Average Customer Tenure in months Rate by Churn Status")
plt.xlabel("Churn Status")
plt.ylabel("Average Customer Tenure in months")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Expertlead Admin\AppData\Local\Temp\ipykernel_5080\1127893061.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_tenure, x="Customer Churn Status", y="Average Customer Tenure in months", palette="pastel")

# %%
# 3. Compare average data usage
avg_data_usage =merged_df.groupby('Customer Churn Status')['Data Usage'].mean()
print("\nAverage Data Usage:\n", avg_data_usage)
# Out:
# Average Data Usage:
#  Customer Churn Status
# No      97.950928
# Yes    102.594014
# Name: Data Usage, dtype: float64

# %%
# Create a DataFrame with the provided averages
avg_data_usage = pd.DataFrame({
    "Customer Churn Status": ["No", "Yes"],
    "Average Data Usage": [97.950928, 102.594014]})

# %%
# Plotting
plt.figure(figsize=(6, 4))
sns.barplot(data=avg_data_usage, x="Customer Churn Status", y="Average Data Usage", palette="pastel")
plt.title("Average Data Usage by Churn Status")
plt.xlabel("Churn Status")
plt.ylabel("Average Data Usage")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Expertlead Admin\AppData\Local\Temp\ipykernel_5080\2713398962.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_data_usage, x="Customer Churn Status", y="Average Data Usage", palette="pastel")

# %%
# To let all the output of the three hypothesis be in one table
avg_satisfaction = pd.Series({'No': 2.905797, 'Yes': 3.049296}, name='Average Satisfaction Rate')
avg_tenure = pd.Series({'No': 30.724638, 'Yes': 33.119718}, name='Average Customer Tenure (months)')
avg_data_usage = pd.Series({'No': 97.950928, 'Yes': 102.594014}, name='Average Data Usage (GB)')

# Combine into a DataFrame
results_df = pd.concat([avg_satisfaction, avg_tenure, avg_data_usage], axis=1)

# Display the table with formatted column headers
print(results_df.to_markdown(floatfmt=".2f"))
# Out:
# |     |   Average Satisfaction Rate |   Average Customer Tenure (months) |   Average Data Usage (GB) |
# |:----|----------------------------:|-----------------------------------:|--------------------------:|
# | No  |                        2.91 |                              30.72 |                     97.95 |
# | Yes |                        3.05 |                              33.12 |                    102.59 |

# %%
# To calculate the percentage of customers using the product per state
# First, we need to count unique customers per state (since some Customer IDs appear multiple times)
customers_per_state = df.drop_duplicates('Customer ID').groupby('State')['Customer ID'].count()

# %%
# Calculate the percentage
percentage_per_state = (customers_per_state / customers_per_state.sum()) * 100

# %%
# Sort for better visualization (optional)
percentage_per_state = percentage_per_state.sort_values(ascending=False)

# %%
# Display the result
print("Percentage of customers per state:")
print(percentage_per_state.round(2).astype(str) + '%')
# Out:
# Percentage of customers per state:
# State
# Abia           3.63%
# Abuja (FCT)    3.43%
# Adamawa        2.22%
# Akwa Ibom      2.02%
# Anambra        3.02%
# Bauchi         4.03%
# Bayelsa        2.02%
# Benue          3.23%
# Borno          3.63%
# Cross River    2.82%
# Delta          2.02%
# Edo            3.23%
# Ekiti          3.23%
# Enugu          3.43%
# Gombe          3.23%
# Imo            3.23%
# Jigawa         2.62%
# Kaduna         1.61%
# Kano           2.02%
# Katsina        3.23%
# Kebbi          2.82%
# Kogi           4.03%
# Kwara          2.22%
# Lagos          1.81%
# Nasarawa       3.02%
# Niger          2.42%
# Ondo           1.81%
# Osun           4.03%
# Oyo            3.43%
# Plateau        2.62%
# Rivers         2.02%
# Sokoto         2.82%
# Taraba         2.62%
# Yobe           3.43%
# Zamfara        3.02%
# Name: Customer ID, dtype: object

# %%
# To see both count and percentage in a nice table:
result = pd.DataFrame({
    'Customer Count': customers_per_state,
    'Percentage': percentage_per_state.round(2)
})
print("\nDetailed breakdown:")
print(result)
# Out:
# Detailed breakdown:
#              Customer Count  Percentage
# State
# Abia                     18        3.63
# Abuja (FCT)              17        3.43
# Adamawa                  11        2.22
# Akwa Ibom                10        2.02
# Anambra                  15        3.02
# Bauchi                   20        4.03
# Bayelsa                  10        2.02
# Benue                    16        3.23
# Borno                    18        3.63
# Cross River              14        2.82
# Delta                    10        2.02
# Edo                      16        3.23
# Ekiti                    16        3.23
# Enugu                    17        3.43
# Gombe                    16        3.23
# Imo                      16        3.23
# Jigawa                   13        2.62
# Kaduna                    8        1.61
# Kano                     10        2.02
# Katsina                  16        3.23
# Kebbi                    14        2.82
# Kogi                     20        4.03
# ...

# %%
# Calculate the total sum of Customer Count
total_customers = result['Customer Count'].sum()

# Add a 'Total' row to the DataFrame
result.loc['Total'] = [total_customers, 100.00]  # Percentage total is 100%

# Display the result with the total
print("\nDetailed breakdown with total:")
print(result.to_markdown(floatfmt=".2f"))
# Out:
# Detailed breakdown with total:
# | State       |   Customer Count |   Percentage |
# |:------------|-----------------:|-------------:|
# | Abia        |            18.00 |         3.63 |
# | Abuja (FCT) |            17.00 |         3.43 |
# | Adamawa     |            11.00 |         2.22 |
# | Akwa Ibom   |            10.00 |         2.02 |
# | Anambra     |            15.00 |         3.02 |
# | Bauchi      |            20.00 |         4.03 |
# | Bayelsa     |            10.00 |         2.02 |
# | Benue       |            16.00 |         3.23 |
# | Borno       |            18.00 |         3.63 |
# | Cross River |            14.00 |         2.82 |
# | Delta       |            10.00 |         2.02 |
# | Edo         |            16.00 |         3.23 |
# | Ekiti       |            16.00 |         3.23 |
# | Enugu       |            17.00 |         3.43 |
# | Gombe       |            16.00 |         3.23 |
# | Imo         |            16.00 |         3.23 |
# ...
